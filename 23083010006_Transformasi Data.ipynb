# %% [markdown]
# # Missing value, Outlier, dan Transformasi data

# %% [markdown]
# Nama: Iin Febyanti
#
# NPM: 23083010006
#
# Kelas: Analisis Data Eksploratif A

# %% [markdown]
# Dataset ini dilakukan pengecekan missing value dan outlier serta mentransformasikan data untuk membantu mempersiapkan dataset yang lebih bersih dan siap untuk analisis lanjutan. Karena dengan adannya missing value dan outlier bisa mengganggu analisis data dan membuat hasil model menjadi tidak akurat.

# %%
import pandas as pd
data = pd.read_csv("C:/Users/IIN FEBYANTI/OneDrive/Sains Data/smoking.csv")
data.head()
data
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 0              1    Male   38       Divorced      No Qualification
# 1              2  Female   42         Single      No Qualification
# 2              3    Male   40        Married                Degree
# 3              4  Female   40        Married                Degree
# 4              5  Female   39        Married          GCSE/O Level
# ...          ...     ...  ...            ...                   ...
# 1686        1687    Male   22         Single      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1688        1689    Male   45        Married      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
# 1690        1691    Male   31        Married                Degree
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 0        British     White    2,600 to 5,200  The North    No           NaN
# 1        British     White       Under 2,600  The North   Yes          12.0
# 2        English     White  28,600 to 36,400  The North    No           NaN
# 3        English     White  10,400 to 15,600  The North    No           NaN
# 4        British     White    2,600 to 5,200  The North    No           NaN
# ...          ...       ...               ...        ...   ...           ...
# 1686    Scottish     White    2,600 to 5,200   Scotland    No           NaN
# 1687     English     White    2,600 to 5,200   Scotland   Yes          20.0
# 1688    Scottish     White   5,200 to 10,400   Scotland    No           NaN
# 1689     English     White    2,600 to 5,200   Scotland   Yes          20.0
# 1690    Scottish     White  10,400 to 15,600   Scotland    No           NaN
#
#       amt_weekdays         type
# 0              NaN          NaN
# 1             12.0      Packets
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 1686           NaN          NaN
# 1687          20.0  Hand-Rolled
# 1688           NaN          NaN
# 1689          20.0      Packets
# 1690           NaN          NaN
#
# [1691 rows x 13 columns]

# %% [markdown]
# # Mengecek missing value

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# gender                      0
# age                         0
# marital_status              0
# highest_qualification       0
# nationality                 0
# ethnicity                   0
# gross_income                0
# region                      0
# smoke                       0
# amt_weekends             1270
# amt_weekdays             1270
# type                     1270
# dtype: int64

# %%
data.dtypes
# Out:
# Unnamed: 0                 int64
# gender                    object
# age                        int64
# marital_status            object
# highest_qualification     object
# nationality               object
# ethnicity                 object
# gross_income              object
# region                    object
# smoke                     object
# amt_weekends             float64
# amt_weekdays             float64
# type                      object
# dtype: object

# %% [markdown]
# # Menghapus missing value
# Jumlah data yang mengalami missing value (amt_weekends, amt_weekdays, dan type) sebesar 75,1% dari data yang tersedia dan data tersebut tidak mempengaruhi data yang lain ketika dihapus. Karena data yang missing value ini merupakan data dari orang yang tidak merokok, sehingga tidak akan ada amt_weekends, amt_weekdays, dan type pada data tersebut.

# %%
df = data.dropna(subset=['amt_weekends', 'amt_weekdays', 'type'])
df.head()
df
# Out:
#       Unnamed: 0  gender  age marital_status highest_qualification  \
# 1              2  Female   42         Single      No Qualification
# 6              7    Male   53        Married                Degree
# 8              9    Male   40         Single              GCSE/CSE
# 9             10  Female   41        Married      No Qualification
# 20            21  Female   34        Married              GCSE/CSE
# ...          ...     ...  ...            ...                   ...
# 1674        1675  Female   31         Single          GCSE/O Level
# 1680        1681    Male   24         Single      No Qualification
# 1683        1684    Male   35        Married      No Qualification
# 1687        1688  Female   49       Divorced      Other/Sub Degree
# 1689        1690  Female   51        Married      No Qualification
#
#      nationality ethnicity      gross_income     region smoke  amt_weekends  \
# 1        British     White       Under 2,600  The North   Yes          12.0
# 6        British     White      Above 36,400  The North   Yes           6.0
# 8        English     White    2,600 to 5,200  The North   Yes           8.0
# 9        English     White   5,200 to 10,400  The North   Yes          15.0
# 20       British     White    2,600 to 5,200  The North   Yes           6.0
# ...          ...       ...               ...        ...   ...           ...
# 1674    Scottish     White  15,600 to 20,800   Scotland   Yes          20.0
# 1680    Scottish     White       Under 2,600   Scotland   Yes          15.0
# 1683    Scottish     White  10,400 to 15,600   Scotland   Yes           3.0
# 1687     English     White    2,600 to 5,200   Scotland   Yes          20.0
# 1689     English     White    2,600 to 5,200   Scotland   Yes          20.0
#
#       amt_weekdays         type
# 1             12.0      Packets
# 6              6.0      Packets
# 8              8.0  Hand-Rolled
# 9             12.0      Packets
# 20            12.0      Packets
# ...            ...          ...
# 1674          10.0      Packets
# 1680          15.0  Hand-Rolled
# 1683          12.0      Packets
# 1687          20.0  Hand-Rolled
# 1689          20.0      Packets
#
# [421 rows x 13 columns]

# %% [markdown]
# # Mengecek outlier
# Dengan membuat boxplot kita bisa melihat outlier pada data tersebut.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['amt_weekends', 'amt_weekdays']])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Mengganti nilai outliers dengan nilai mean
# Karena data ini tidak terdapat banyak outliers maka mengganti outliers dengan mean akan tetap mencerminkan kebiasaan merokok dari populasi data tersebut (tidak akan terlalu mempengaruhi hasil keseluruhan).

# %%
from scipy import stats
data_fix = df.copy()

for column in ['amt_weekends', 'amt_weekdays']:
    Q1 = data_fix[column].quantile(0.25)
    Q3 = data_fix[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    mean = data_fix[column].mean()  
    data_fix[column] = data_fix[column].apply(
        lambda x: mean if x < lower_bound or x > upper_bound else x  
    )

data_fix.head()
# Out:
#     Unnamed: 0  gender  age marital_status highest_qualification nationality  \
# 1            2  Female   42         Single      No Qualification     British
# 6            7    Male   53        Married                Degree     British
# 8            9    Male   40         Single              GCSE/CSE     English
# 9           10  Female   41        Married      No Qualification     English
# 20          21  Female   34        Married              GCSE/CSE     British
#
#    ethnicity     gross_income     region smoke  amt_weekends  amt_weekdays  \
# 1      White      Under 2,600  The North   Yes          12.0          12.0
# 6      White     Above 36,400  The North   Yes           6.0           6.0
# 8      White   2,600 to 5,200  The North   Yes           8.0           8.0
# 9      White  5,200 to 10,400  The North   Yes          15.0          12.0
# 20     White   2,600 to 5,200  The North   Yes           6.0          12.0
#
#            type
# 1       Packets
# 6       Packets
# 8   Hand-Rolled
# 9       Packets
# 20      Packets

# %% [markdown]
# # Melakukan transformasi data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data_fix = df.copy()

for column in ['amt_weekends', 'amt_weekdays']:
    Q1 = data_fix[column].quantile(0.25)
    Q3 = data_fix[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    mean = data_fix[column].mean()  
    data_fix[column] = data_fix[column].apply(
        lambda x: mean if x < lower_bound or x > upper_bound else x  
    )

plt.figure(figsize=(14, 6))  # Adjust the size as needed

#bokplot setelah ditransformasi
plt.subplot(1, 2, 2)
sns.boxplot(data=data_fix[['amt_weekends', 'amt_weekdays']])
plt.title('Setelah outlier diganti mean')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # Memvisulaisasikan data sebelum dan sesudah transformasi¶

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Menghitung rata-rata sebelum transformasi
mean_before = df[['amt_weekends', 'amt_weekdays']].mean()

# Menghitung rata-rata setelah transformasi
mean_after = data_fix[['amt_weekends', 'amt_weekdays']].mean()

plt.figure(figsize=(14, 6))

# Grafik Sebelum Transformasi
plt.subplot(1, 2, 1)
sns.barplot(x=mean_before.index, y=mean_before.values, palette='viridis')
plt.title('Sebelum Transformasi')
plt.ylabel('Jumlah Merokok')
plt.xlabel('Kategori')
plt.xticks(rotation=0)

# Grafik Setelah Transformasi
plt.subplot(1, 2, 2)
sns.barplot(x=mean_after.index, y=mean_after.values, palette='viridis')
plt.title('Setelah Transformasi')
plt.ylabel('Jumlah Merokok')
plt.xlabel('Kategori')
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()
